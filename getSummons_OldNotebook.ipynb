# %%
import requests as rqimport zipfile as zpimport StringIOimport osimport pandas as pd

# %%
def makeTime():    """Make all the links to the data we want. Data doesn't start until 2011_08"""    year = ["2013","2012","2011"]    month = ["01","02","03","04","05","06","07","08","09","10","11","12"]    container = []    for y in year:        for m in month:            if (y != "2011") or (m not in ["01","02","03","04","05","06","07"]):                container.append(y+"_"+m)    return container

# %%
dates = makeTime()

# %%
if not os.path.isfile("citySummons.csv"):    for d in dates:        r = rq.get("http://www.nyc.gov/html/nypd/downloads/zip/traffic_data/{}_sum.zip".format(d))        z = zp.ZipFile(StringIO.StringIO(r.content))        z.extract("citysum.xlsx", path="citysum/")        os.rename("citysum/citysum.xlsx","citysum/citysum{}.xlsx".format(d))    with open('citySummons.csv','wb') as f:    for d in dates:        raw = pd.read_excel("citysum/citysum{}.xlsx".format(d),0, skiprows=2, index_col=None, names=["type","mtd","ytd"])        backSafely = {'type': raw.ix[0]['type'].split('\n')[1], 'mtd': raw.ix[0]['mtd'].split('\n')[1], 'ytd':raw.ix[1]['ytd']}        otherMovers = {'type': raw.ix[34]['type'].split('\n')[0], 'mtd': raw.ix[34]['mtd'].split('\n')[0], 'ytd':raw.ix[34]['ytd']}        totalMovers = {'type': raw.ix[34]['type'].split('\n')[1], 'mtd': raw.ix[34]['mtd'].split('\n')[1], 'ytd':raw.ix[35]['ytd']}        df = raw[2:34]        df = df.append([backSafely, otherMovers, totalMovers], ignore_index=True)        df['date'] = d        df['year'] = df['date'].apply(lambda x: x.split('_')[0])        df['month'] = df['date'].apply(lambda x: x.split('_')[1])        df.to_csv(f, header=False, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /media/sf_LinuxShare/visionzero/<ipython-input-4-f25fb3edbfd2> in <module>()
#       1 for d in dates:
# ----> 2     r = rq.get("http://www.nyc.gov/html/nypd/downloads/zip/traffic_data/{}_sum.zip".format(d))
#       3     z = zp.ZipFile(StringIO.StringIO(r.content))
#       4     z.extract("citysum.xlsx", path="citysum/")
#       5     os.rename("citysum/citysum.xlsx","citysum/citysum{}.xlsx".format(d))
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ...

# %%
#df = pd.read_csv("citySummons.csv", names=["type","mtd","ytd","date"])

# %%
df
# Out:
#                                   type    mtd    ytd     date  year month0   Brake Lights (Defect.or  Improper)   2478   2478  2013_01  2013    011                 Bus Lane, Driving in    432    432  2013_01  2013    012                           Cell Phone  11244  11244  2013_01  2013    013               Commercial Veh on Pkwy     89     89  2013_01  2013    014                     Defective Brakes     29     29  2013_01  2013    015                         Disobey Sign  14677  14677  2013_01  2013    016                    Equipment (Other)    587    587  2013_01  2013    017                   Fail to Keep Right     29     29  2013_01  2013    018                       Fail to Signal   1394   1394  2013_01  2013    019               Fail to Stop on Signal   3523   3523  2013_01  2013    0110               Following Too Closely    106    106  2013_01  2013    0111    Headlights (Defect. or Improper)   2694   2694  2013_01  2013    0112                     Improper Lights    384    
# ...

# %%
df.groupby('date').size()
# Out:
# date2011_08    352011_09    352011_10    352011_11    352011_12    352012_01    352012_02    352012_03    352012_04    352012_05    352012_06    352012_07    352012_08    352012_09    352012_10    352012_11    352012_12    352013_01    352013_02    352013_03    352013_04    352013_05    352013_06    352013_07    352013_08    352013_09    352013_10    352013_11    352013_12    35dtype: int64

# %%
df.ix[0:70:5]
# Out:
#                                   type    mtd    ytd     date0   Brake Lights (Defect.or  Improper)   2478   2478  2013_015                         Disobey Sign  14677  14677  2013_0110               Following Too Closely    106    106  2013_0115             Improper/Missing Plates    188    188  2013_0120                         Safety Belt   9621   9621  2013_0125                        Truck Routes    441    441  2013_0130                        Unregistered   1017   1017  2013_0135  Brake Lights (Defect.or  Improper)   2611   5090  2013_0240                        Disobey Sign  12476  27154  2013_0245               Following Too Closely    108    214  2013_0250             Improper/Missing Plates    204    392  2013_0255                         Safety Belt   9479  19101  2013_0260                        Truck Routes    481    922  2013_0265                        Unregistered    924   1941  2013_0270  Brake Lights (Defect.or  Improper)   2641   7735  2013_03[15 rows x 4 columns]

# %%
aggMtd = df[['type','year','mtd']].groupby(['type','year']).sum()

# %%
aggMtd
# Out:
#                                             mtdtype                               year        Backing Unsafely                   2011     353                                   2012    1226                                   2013    1568Brake Lights (Defect.or  Improper) 2011   10961                                   2012   30388                                   2013   27038Bus Lane, Driving in               2011    2202                                   2012    8782                                   2013    5472Cell Phone                         2011   56674                                   2012  145254                                   2013  126382Commercial Veh on Pkwy             2011     504                                   2012     862                                   2013    1063Defective Brakes                   2011     131                                   2012     502                                   2013     383Disobey Sign                       2011   45351           
# ...

# %%
aggYtd = df[['type','ytd','year']][df.month == "12"].set_index(['type','year'])

# %%
aggCheck = aggMtd.join(aggYtd)

# %%
aggCheck['dif'] = aggCheck.mtd - aggCheck.ytd

# %%
aggCheck.sort('dif',ascending=False)[0::2]
# Out:
#                                              mtd      ytd     diftype                               year                          TOTAL Movers                       2012  1033658  1020754   12904Other Movers                       2012    63216    60274    2942Tinted Windows                     2012    97023    95866    1157Bus Lane, Driving in               2012     8782     7756    1026Uninsured                          2012    56388    56108     280Not Giving R of W to Pedes.        2012    11918    11698     220Brake Lights (Defect.or  Improper) 2012    30388    30283     105One Way Street                     2012     4556     4489      67U-Turn                             2012     3943     3912      31Defective Brakes                   2012      502      483      19Improper/Missing Plates            2013     2962     2958       4                                   2012     2474     2473       1One Way Street                     2013     4985     4985       0Commercial Veh on Pkwy 
# ...
